# %% [markdown]
# <img style="display:block; float:left" src="http://static.tumblr.com/6d1b718e0ca705fd853b14bb89cfd9bb/yo7wuqs/K6mmprrvf/tumblr_static_melbdjango.png"/>

# %% [markdown]
# <h1 style="text-align:center; color:green"> Natural Language Processing with Python/NLTK </h1>
#
#
# <h1 style="text-align:center"> Luciano M. Guasco </h1>
#
# <h1 style="text-align:center"> @luchux, github.com/luchux </h2>

# %% [markdown]
# <img style="display:inline-block; float:center" src="http://adamhoddinott.com/static/img/common-code-logo.png"/>

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <h2> Why me? I am not A. Turing!!!! </h2>

# %%
from IPython.display import Image
Image(filename='imgs/viclone.png', embed=True)

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <h2 style="text-align:center"> Topics during this presentation: <h2>

# %% [markdown]
# <img style="position:absolute;bottom:-10px;right:-20px; height:100px;width:100px" src="http://4.bp.blogspot.com/_TYtL3iq-5_8/SKVr5ItgvPI/AAAAAAAAB1A/WWzn2cjDXC4/s320/bender.gif">

# %% [markdown]
# <section style="font-size:18px">
# <ul>
# <li>Definition</li>
# <li>Motivation</li>
# <li>Why Python?</li>
# <li>Basic NLP operations
#     <ul><li>Tokenization</li>
#         <li>Part of Speech (POS)</li>
#         <li>Chunking </li>
#         <li>Parsing</li>
#     </ul>
# </li>
# <li>Text Classification</li>
# <li>Sentiment Analysis</li>
# </ul>
# </section>

# %% [markdown]
# <p style="text-align:centre; font-color:blue; font-size:30px">THERE IS AS YET INSUFFICIENT DATA FOR A MEANINGFUL ANSWER :: Isaac Asimov <p>
# <br><br><br><br>

# %% [markdown]
# <h1>Introduction</h1>
# <hr>

# %% [markdown]
# <h2><li>NLP: Field of Computer Science and Linguistics: interaction between computers and human languages.</li> </h2>

# %% [markdown]
# <h2><li>It is a wide field, where the main objective is to enrich computer algorithms with the capacity of handling natural language.
#     </li></h2>

# %% [markdown]
# <h2><li>By “natural language”: the daily use of human language, evolving dynamically according to popular usage.</li></h2>

# %% [markdown]
# <h2><li>The complexity:  Ambiguity inherited in human language. Different words with same meaning, same word with different meanings,  non deterministic and non computable grammars, difficulty of represent in the computer the real world semantic...</li></h2>

# %% [markdown]
# <h1>Motivation</h1>
# <hr>

# %% [markdown]
# <h2><li>Old data and information is being transformed in digital media. Mostly every new data is generated in digital form.</li> <h2>

# %% [markdown]
# <h2><li>We need the capacity to automatically recognize content in this data. We need the power to compute huge operations over this information, replacing the hard/slow work needed by a human.</li></h2>

# %% [markdown]
# - Automatic Summarization
# - Bots! Pew bot, Hubbot! image me drunk.
# - Translations
# - Named Entity Recognition
# - Natural Language generation
# - Optical Character Recognition (OCR)
# - Part of Speech tagging (POS)
# - Parsing
# - Question Answering
# - Sentiment Analysis
# - Speech Recognition
# - Word sense disambiguation
# - Information Retrieval
# - Stemming
# - Heaps More!

# %% [markdown]
# <h1> Why Python? </h1>
# <hr>
# <h2 style="float:right"> Really!?</2>

# %% [markdown]
# <h2>"Everything Should Be Made as Simple as Possible, But Not Simpler" A.Einstein</h2>

# %% [markdown]
# <h4> for example inserting an local image in IPython html... </h4>

# %%
from IPython.display import Image
Image(filename='imgs/c1.png', embed=True)

# %%
from IPython.display import Image
Image(filename='imgs/c2.png', embed=True)

# %% [markdown]
# <h2><li>"Why A? because not B" is a good, but not the best argument. Python is handy, flexible, and... you know all the rest.</li></h2>

# %% [markdown]
# <h2><li> Natural Language Toolkit in Python. SciKit Learning algorithms in Python.</li></h2>

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# <h1>Basic Operations of NLP </h1>
# <h1>Tokenization</h1>
# <hr>
#
# <h2><li>The process of splitting text into smaller pieces or units. </li>
# <li>We vant tokenize text into sentences, and sentences into tokens.</li>
#     <li>The library provides a tokenization module, nltk.tokenize</li>
# </h2>

# %%
import nltk #dirty, but we will use it laterz
from nltk import sent_tokenize, word_tokenize

# %%
sentences = sent_tokenize("The world is huge. All human populations possess language! This includes populations, \
such as the Tasmanians and the Andamanese, who may have been isolated from the Old World continents for as long as 40,000 years. \
All the pugs speak a language that we can not understand."
) 

sentences
# Out:
# ['The world is huge.',
#  'All human populations possess language!',
#  'This includes populations, such as the Tasmanians and the Andamanese, who may have been isolated from the Old World continents for as long as 40,000 years.',
#  'All the pugs speak a language that we can not understand.']

# %%
tokens = word_tokenize(sentences[2])

# %%
tokens
# Out:
# ['This',
#  'includes',
#  'populations',
#  ',',
#  'such',
#  'as',
#  'the',
#  'Tasmanians',
#  'and',
#  'the',
#  'Andamanese',
#  ',',
#  'who',
#  'may',
#  'have',
#  'been',
#  'isolated',
#  'from',
#  'the',
#  'Old',
#  'World',
#  'continents',
#  'for',
#  'as',
#  'long',
#  'as',
#  '40,000',
#  'years',
#  '.']

# %% [markdown]
# <h1>POS Tagging</h1>
# <hr>
# <h2><li>The process of tagging each word, into a lexical category: Noun, Adjective, Verb, etc... </li></h2>
# <h2><li>This is useful, for higher analysis level. For example, disambiguation, structure analysis, as we will see further </li></h2>

# %% [markdown]
# <img src="http://files.doobybrain.com/wp-content/uploads/2009/05/im-so-adjective-i-verb-nouns.jpg" height=300px width=300px>

# %%
from nltk import pos_tag 
#this is a Classifier, given a token assign a class
#pos_tag Already defined in the library. We can train our own.

# %%
tags = pos_tag(tokens)

# %%
tags
# Out:
# [('This', 'DT'),
#  ('includes', 'VBZ'),
#  ('populations', 'NNS'),
#  (',', ','),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('Tasmanians', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Andamanese', 'NNP'),
#  (',', ','),
#  ('who', 'WP'),
#  ('may', 'MD'),
#  ('have', 'VB'),
#  ('been', 'VBN'),
#  ('isolated', 'VBN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('Old', 'NNP'),
#  ('World', 'NNP'),
#  ('continents', 'NNS'),
#  ('for', 'IN'),
#  ('as', 'RB'),
#  ('long', 'JJ'),
#  ('as', 'IN'),
#  ('40,000', 'CD'),
#  ('years', 'NNS'),
#  ('.', '.')]

# %% [markdown]
# <img src="https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSFZ2l8g_3316qek21ZEIkTS0WIYs8-lfTvXtO3YGWHEGpdDiMG">

# %% [markdown]
# <h1>Word Senses</h1>
# <h3><li>In linguistics, a word sense is one of the meanings of a word. </li></h3>
# <h3><li>Until now, we worked with tokens and POS. So, for instance in "the man sit down on the bench near the river.", the token [bench] could be bench as a constructed object by humans where people sit, or the natural side where the river meets the land.</li></h3>
#
# <h3><li>WordNet: A semantic graph for words. NLTK provides a interface to the API </li></h3>

# %%
from IPython.display import Image
Image(filename='imgs/ws1.png', embed=True)

# %%
from IPython.display import Image
Image(filename='imgs/ws2.png', embed=True)

# %% [markdown]
# <h3> Lets see some functions to handle meanings in tokens </h3>
# <h4> wordnet provides the concept of synsets, as syntactic units for tokens

# %%
from nltk.corpus import wordnet as wn #loading wordnet module

wn.synsets('human')
# Out:
# [Synset('homo.n.02'),
#  Synset('human.a.01'),
#  Synset('human.a.02'),
#  Synset('human.a.03')]

# %%
wn.synsets('human')[0].definition
# Out:
# 'any living or extinct member of the family Hominidae characterized by superior intelligence, articulate speech, and erect carriage'

# %%
wn.synsets('human')[1].definition
# Out:
# 'characteristic of humanity'

# %%
human = wn.synsets('Human',pos=wn.NOUN)[0]
human
# Out:
# Synset('homo.n.02')

# %%
human.hypernyms()
# Out:
# [Synset('hominid.n.01')]

# %%
human.hyponyms()
# Out:
# [Synset('world.n.08'),
#  Synset('homo_habilis.n.01'),
#  Synset('homo_sapiens.n.01'),
#  Synset('rhodesian_man.n.01'),
#  Synset('homo_soloensis.n.01'),
#  Synset('neandertal_man.n.01'),
#  Synset('homo_erectus.n.01')]

# %%
bike = wn.synsets('bicycle')[0]
bike
# Out:
# Synset('bicycle.n.01')

# %%
girl = wn.synsets('girl')[1]
girl
# Out:
# Synset('female_child.n.01')

# %%
bike.wup_similarity(human)
# Out:
# 0.34782608695652173

# %%
girl.wup_similarity(human)
# Out:
# 0.5217391304347826

# %% [markdown]
# <h1>Chunks</h1>
# <hr>
#
# <h2><li>Chunking is the process of collecting patterns of Part of Speech together, representing some meaning.</li></h2>
# <h2><li>Analysis of a sentence which identifies the constituents (noun groups - "[The red tree] grows near the river", verbs, verb groups, etc.)</li></h2>
# <h2><li>Our goal is detect into digital text, thing like "where are different entities located," or "which person is employed by what organization".</li></h2>
# <h2><li>Its the way in which we extract structured data (entities and relations) from unstructured text</li></h2>

# %% [markdown]
# <img width=580px height=150px src="http://nltk.googlecode.com/svn/trunk/doc/images/chunk-segmentation.png" >

# %%
from nltk import word_tokenize,pos_tag
from nltk.chunk import RegexpParser

chunker = RegexpParser(r'''
NP:
{<DT><NN.*><.*>*<NN.*>}
}<VB.*>{
''')

# %%
print tags
print chunker.parse(tags)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-351e6f6b6276> in <module>()
# ----> 1 print tags
#       2 print chunker.parse(tags)
#
# NameError: name 'tags' is not defined

# %% [markdown]
# <h1>Entity Recognition - Chunking</h1>
# <hr>
# <h2><li>Part of chunking. We look for chunks of Part Of Speech.</li></h2>
# <h2><li>The goal is to detect entities: Person, Location, Time, etc.</li></h2>
# <h2><li>I will use here the librare ne_chunker. But we can train our own models, or provide grammar rules as before</li></h2>

# %%
from nltk.chunk import ne_chunk

# %%
sentence = "Daryl A. is the head of the coworking place Commoncode Corp. from where many people work in Melbourne, Australia."
pos_tags = pos_tag(word_tokenize(sentence))
pos_tags
# Out:
# [('Daryl', 'NNP'),
#  ('A.', 'NNP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('head', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('coworking', 'NN'),
#  ('place', 'NN'),
#  ('Commoncode', 'NNP'),
#  ('Corp.', 'NNP'),
#  ('from', 'IN'),
#  ('where', 'WRB'),
#  ('many', 'JJ'),
#  ('people', 'NNS'),
#  ('work', 'VBP'),
#  ('in', 'IN'),
#  ('Melbourne', 'NNP'),
#  (',', ','),
#  ('Australia', 'NNP'),
#  ('.', '.')]

# %%
ne_chunk(pos_tags)
# Out:
# Tree('S', [Tree('PERSON', [('Daryl', 'NNP')]), ('A.', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('head', 'NN'), ('of', 'IN'), ('the', 'DT'), ('coworking', 'NN'), ('place', 'NN'), Tree('ORGANIZATION', [('Commoncode', 'NNP')]), ('Corp.', 'NNP'), ('from', 'IN'), ('where', 'WRB'), ('many', 'JJ'), ('people', 'NNS'), ('work', 'VBP'), ('in', 'IN'), Tree('GPE', [('Melbourne', 'NNP')]), (',', ','), Tree('GPE', [('Australia', 'NNP')]), ('.', '.')])

# %%
# Out:
# Most Informative Features
#              has(didn't) = True           advent : learne =     39.6 : 1.0
#                has(gone) = True           scienc : learne =     35.7 : 1.0
#              has(played) = True           review : learne =     32.3 : 1.0
#               has(music) = True           review : learne =     32.3 : 1.0
#              has(wasn't) = True           myster : learne =     30.9 : 1.0
#               has(woman) = True           fictio : learne =     28.8 : 1.0
#               has(can't) = True           scienc : learne =     27.8 : 1.0
#             has(dropped) = True           advent : learne =     27.4 : 1.0
#                 has(ran) = True           advent : learne =     27.4 : 1.0
#              has(walked) = True           myster : learne =     26.6 : 1.0
#             has(nuclear) = True           editor : learne =     25.8 : 1.0
#            has(watching) = True           romanc : learne =     25.8 : 1.0
#            has(wouldn't) = True           advent : learne =     25.4 : 1.0
#             has(watched) = True           advent : learne =     25.4 : 1.0
#                 has(sat) = True           advent : learne =     25.4 : 1.0
#                 has(boy) = True           fictio : learne =     25.1 : 1.0
#             has(playing) = True           review : learne =     24.7 : 1.0
#              has(season) = True           review : learne =     24.7 : 1.0
#             has(musical) = True           review : learne =     24.7 : 1.0
#              has(you're) = True            humor : learne =     23.1 : 1.0
#             has(stopped) = True           myster : learne =     22.4 : 1.0
#           has(afternoon) = True           fictio : learne =     21.4 : 1.0
#              has(pulled) = True           advent : learne =     21.3 : 1.0
#            has(services) = True           govern : belles =     20.8 : 1.0
#              has(that's) = True           myster : learne =     20.2 : 1.0
#                 has(yes) = True           myster : learne =     20.2 : 1.0
#                has(eyes) = True           advent : learne =     20.1 : 1.0
#                has(wait) = True           scienc : learne =     19.8 : 1.0
#                has(game) = True           scienc : learne =     19.8 : 1.0
#              has(stayed) = True           scienc : learne =     19.8 : 1.0
# fiction

# %% [markdown]
# <h1> Excercise A: Frequency Distribution of Words, Lenguage Models </h1>
# <hr>
# <h2><li> Lets track the last month messages from our campfire chat room</li></h2>
# <h2><li> Lets see most used words</li></h2>
# <h2><li> And generate very probable "random" sentences </li></h2>

# %%
from camplight import Request, Campfire
from settings import CAMPFIRE_BOT

# %%
campfire_request = Request('https://commoncode.campfirenow.com', CAMPFIRE_BOT)
campfire = Campfire(campfire_request)

# %%
room = campfire.room('Common Code')
room.join()

# %%
alldays = []
for i in range(1,30):
    day = room.transcript("2013/07/" + str(i))
    alldays.extend(day)

# %%
import pickle

# %%
#fwrite = open('transcript.july','w+')
#pickle.dump(alldays, fwrite)
#fwrite.close()

# %%
fopen = open('transcript.july','r')
alldays = pickle.load(fopen)

# %%
len(alldays)
# Out:
# 15825

# %%
import pandas as pd

# %%
df = pd.DataFrame(alldays)

df = df[df.body.notnull()] 
df = df[df.user_id != 1297189] #removing null messages

# %%
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12122 entries, 9 to 15807
# Data columns (total 10 columns):
# body           12122  non-null values
# created_at     12122  non-null values
# description    3  non-null values
# id             12122  non-null values
# room_id        12122  non-null values
# starred        12122  non-null values
# tweet          3  non-null values
# type           12122  non-null values
# url            3  non-null values
# user_id        12122  non-null values
# dtypes: bool(1), float64(1), int64(2), object(6)

# %%
from nltk.corpus import stopwords

# %%
stops = stopwords.words('english')
stops.extend('.,[,],,,(,),;,\',?,",:,<,>,n\'t,|,#,\'s,\",\'re,\'ve,\'ll,\'d,\'re'.split(','))

# %%
freq_dist = nltk.FreqDist()
for message in df.body:
    for word in word_tokenize(message):
        if word not in stops:
            freq_dist.inc(word)

# %%
import matplotlib
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5,10.5)
freq_dist.plot(10,50,title="Test", figure=fig)

# %%
# Out:
# [u',',
#  u'I',
#  u'!',
#  u'...',
#  u"''",
#  u'-',
#  u'hubot',
#  u'Mark',
#  u'http',
#  u'Hellewell',
#  u'``',
#  u'P',
#  u'yeah',
#  u'Gamaliel',
#  u'Ch.',
#  u'Daryl',
#  u'like',
#  u'get',
#  u'https',
#  u'Antony',
#  u'Matt',
#  u'time',
#  u'user',
#  u"'m",
#  u'Blair',
#  u'Dan',
#  u'hofbot',
#  u'pew',
#  u'Peade',
#  u"'ll",
#  u'Y3K',
#  u'oh',
#  u'need',
#  u'see',
#  u'work',
#  u'good',
#  u'pork',
#  u'right',
#  u'think',
#  u'well',
#  u"'re",
#  u'Anthony',
#  u'Briggs',
#  u'git',
#  u'image',
#  u'puppet',
#  u'say',
#  u"'d",
#  u'.png',
#  u'Brenton',
#  u'hofbot/master',
#  u'ok',
#  u'one',
#  u'roll',
#  u'stuff',
#  u'David',
#  u'Ok',
#  u'check',
#  u'query',
#  u'role',
#  u'thing',
#  u'use',
#  u'would',
#  u"'ve",
#  u'3',
#  u'Curtis',
#  u'around',
#  u'detached',
#  u'echo',
#  u'go',
#  u'help',
#  u'it\u2019s',
#  u'make',
#  u'nice',
#  u'really',
#  u'still',
#  u'sure',
#  u'%',
#  u'Burles',
#  u'Did',
#  u'It',
#  u'Maloney',
#  u'could',
#  u'entry',
#  u'etc',
#  u'know',
#  u'line',
#  u'luchux',
#  u'pretty',
#  u'request',
#  u'show',
#  u'somebody',
#  u'tomorrow',
#  u'worktree',
#  u'Cleeland',
#  u'Django',
#  u'H',
#  u'Oh',
#  u'Trello',
#  u'What',
#  u'added',
#  u'bit',
#  u'copper',
#  u'cron',
#  u'disk',
#  u'django',
#  u'first',
#  u'got',
#  u'look',
#  u'looks',
#  u'master',
#  u'might',
#  u'pull',
#  u'read',
#  u'repo',
#  u'//s3.amazonaws.com/barkpost-assets/50+GIFs/7.gif',
#  u'1',
#  u'Dadhania',
#  u'Gaurav',
#  u'Hmm',
#  u'Hofbot',
#  u'New',
#  u'Relic',
#  u'Thanks',
#  u'The',
#  u'Well',
#  u'actually',
#  u'agent',
#  u'ah',
#  u'apollo',
#  u'better',
#  u'can\u2019t',
#  u'code',
#  u'cool',
#  u'done',
#  u'everything',
#  u'fix',
#  u'game',
#  u'logs',
#  u'lol',
#  u'puppetmaster',
#  u'script',
#  u'seems',
#  u'shit',
#  u'today',
#  u'+',
#  u'2',
#  u'@',
#  u'Bubbly',
#  u'Code',
#  u'Logs',
#  u'already',
#  u'also',
#  u'back',
#  u'call',
#  u'card',
#  u'command',
#  u'completely',
#  u'current',
#  u'different',
#  u'exactly',
#  u'fucking',
#  u'guess',
#  u'gzip',
#  u'haha',
#  u'mcflurry',
#  u'monoliths',
#  u'package',
#  u'pewbot',
#  u'phone',
#  u'room',
#  u'server',
#  u'set',
#  u'started',
#  u'sync',
#  u'talking',
#  u'thats',
#  u'tho',
#  u'title',
#  u'trying',
#  u'wait',
#  u'want',
#  u'yet',
#  u'&',
#  u"'cause",
#  u'//git.io/HDJs5Q',
#  u'//www.youtube.com/watch',
#  u'4',
#  u'API',
#  u'B',
#  u'Common',
#  u'How',
#  u'I\u2019m',
#  u'LB',
#  u'Looks',
#  u'OK',
#  u'Telstra',
#  u'Yeah',
#  u'able',
#  u'alerts',
#  u'badass',
#  u'beep',
#  u'big',
#  u'campfire',
#  u'case',
#  u'changes',
#  u'coffee',
#  u'crontab',
#  u'day',
#  u'elpis',
#  u'end',
#  u'even',
#  u'event',
#  u'every',
#  u'friend',
#  u'going',
#  u'guitarist',
#  u'idea',
#  u'instead',
#  u'internet',
#  u'kinda',
#  u'left',
#  u'list',
#  u'little',
#  u'lot',
#  u'mine',
#  u'morning',
#  u'much',
#  u'office',
#  u'old',
#  u'perhaps',
#  u'phrase',
#  u'post',
#  u'pug',
#  u'put',
#  u'radar',
#  u're',
#  u'reckon',
#  u'returns',
#  u'send',
#  u'team',
#  u'test',
#  u'whole',
#  u'worked',
#  u'working',
#  u'yes',
#  u'/',
#  u'0',
#  u'10',
#  u'2013-08-07',
#  u'A',
#  u'ADSL',
#  u'AFAIK',
#  u'But',
#  u'C',
#  u'Checking',
#  u'Display',
#  u'Do',
#  u'Everskill',
#  u'Hey',
#  u'IN',
#  u'MelbDjango',
#  u'Morning',
#  u'NR',
#  u'Nice',
#  u'No',
#  u'Nope',
#  u'Reply',
#  u'Returns',
#  u'Searches',
#  u'So',
#  u'That',
#  u'You',
#  u'actions',
#  u'afraid',
#  u'album',
#  u'area',
#  u'bad',
#  u'best',
#  u'branch',
#  u'brb',
#  u'bunch',
#  u'ca',
#  u'cbd',
#  u'change',
#  u'close',
#  u'come',
#  u'core',
#  u'create',
#  u'daft',
#  u'done.',
#  u'dunno',
#  u'eh',
#  u'email',
#  u'esky',
#  u'expression',
#  u'fault',
#  u'fine',
#  u'found',
#  u'fuck',
#  u'hellewell',
#  u'hofstadter',
#  u'iPad',
#  u'im',
#  u'interesting',
#  u'issue',
#  u'knows',
#  u'landline',
#  u'last',
#  u'later',
#  u'level',
#  u'link',
#  u'log',
#  u'lunch',
#  u'made',
#  u'mark',
#  u'mean',
#  u'minutes',
#  u'missing',
#  u'moved',
#  u'mustache',
#  u'never',
#  u'new',
#  u'nothing',
#  u'objects',
#  u'pic',
#  u'possible',
#  u'probably',
#  u'punk',
#  u'puppetmaster/master',
#  u'push',
#  u'pushed',
#  u'python',
#  u'ran',
#  u'reason',
#  u'remove',
#  u'resource',
#  u'return',
#  u'roles',
#  u'run',
#  u'saw',
#  u'site',
#  u'slide',
#  u'someone',
#  u'something',
#  u'sorry',
#  u'source',
#  u'space',
#  u'start',
#  u'stop',
#  u'super',
#  u'target',
#  u'text',
#  u'thanks',
#  u'though',
#  u'together',
#  u'token',
#  u'total',
#  u'trello',
#  u'tweet',
#  u'used',
#  u'using',
#  u'view',
#  u'waiting',
#  u'wanted',
#  u'wat',
#  u'waves',
#  u'weapons',
#  u'window',
#  u'without',
#  u'works',
#  u'wrong',
#  u'{',
#  u'}',
#  u'--',
#  u'-exec',
#  u'//',
#  u'//lh5.googleusercontent.com/-MlDz2f26eqQ/UY8qz1syY_I/AAAAAAAAA4o/EWq1ENUb71Y/95ff6c96.gif',
#  u'//www.bom.gov.au/radar/IDR023.gif',
#  u'/proc',
#  u'100',
#  u'28',
#  u'4/4',
#  u'7',
#  u'Adam',
#  u'Add',
#  u'And',
#  u'Anyone',
#  u'Apollo',
#  u'BOM',
#  u'Back',
#  u'Beta',
#  u'C.',
#  u'CC',
#  u'CSRF',
#  u'Displays',
#  u'Find',
#  u'First',
#  u'Fix',
#  u'Friday',
#  u'GOING',
#  u'Google',
#  u'Got',
#  u'HTTP',
#  u'Have',
#  u'Hi',
#  u'Hoddinott',
#  u'Hofstadter',
#  u'Hola',
#  u'Host\u2013only',
#  u'If',
#  u'Images',
#  u'Just',
#  u'Melb',
#  u'Mentorloop',
#  u'Merge',
#  u'Mr.',
#  u'My',
#  u'N',
#  u'NAT',
#  u'Nicholas',
#  u'RKM',
#  u'RYMKADEPSEL',
#  u'Sanders',
#  u'Screen',
#  u'Scrum',
#  u'Shot',
#  u'Should',
#  u'Sorry',
#  u'There',
#  u'This',
#  u'To',
#  u'Toggl',
#  u'Tuesday',
#  u'We',
#  u'Woah',
#  u'Yes',
#  u'Yo',
#  u'^',
#  u'access',
#  u'according',
#  u'action',
#  u'admin',
#  u'afk',
#  u'ages',
#  u'ago',
#  u'akamai',
#  u'amazing',
#  u'animate',
#  u'another',
#  u'anybody',
#  u'anyone',
#  u'anything',
#  u'anyway',
#  u'assign',
#  u'attacked',
#  u'away',
#  u'aye',
#  u'bag',
#  u'based',
#  u'bbl',
#  u'believe',
#  u'bigger',
#  u'bitcoin',
#  u'bloody',
#  u'board',
#  u'bubbly',
#  u'bug',
#  u'bullshit',
#  u'cafe',
#  u'cards',
#  u'cat',
#  u'celebrate',
#  u'chats',
#  u'chips',
#  u'clear',
#  u'closed',
#  u'comfortable',
#  u'coming',
#  u'commands',
#  u'commit',
#  u'commits',
#  u'commoncode/hofbot',
#  u'complaining',
#  u'complexity',
#  u'connect',
#  u'console',
#  u'contents',
#  u'cool.',
#  u'damn',
#  u'data',
#  u'debugging',
#  u'delete',
#  u'delta',
#  u'deploy',
#  u'deployed',
#  u'description',
#  u'developer',
#  u'died',
#  u'distracted',
#  u'doesn\u2019t',
#  u'earlier',
#  u'easily',
#  u'entries',
#  u'fabric',
#  u'find',
#  u'fixed',
#  u'fixing',
#  u'food',
#  u'form',
#  u'full',
#  u'fun',
#  u'getting',
#  u'gim',
#  u'github',
#  u'github.com',
#  u'give',
#  u'given',
#  u'great',
#  u'guy',
#  u'guys',
#  u'hah',
#  u'hahaha',
#  u'handset',
#  u'happen',
#  u'happened',
#  u'happening',
#  u'hard',
#  u'head',
#  u'hey',
#  u'hi',
#  u'hoftbot',
#  u'hole',
#  u'hook',
#  u'hooked',
#  u'hours',
#  u'however',
#  u'hur',
#  u'id',
#  u'ignore',
#  u'important',
#  u'inside',
#  u'install',
#  u'instance',
#  u'jars',
#  u'job',
#  u'keep',
#  u'kernel',
#  u'keyword',
#  u'lawl',
#  u'least',
#  u'less',
#  u'light',
#  u'likely',
#  u'litre',
#  u'load',
#  u'login',
#  u'long',
#  u'looked',
#  u'maintenance',
#  u'management',
#  u'manifest',
#  u'manually',
#  u'map',
#  u'meme',
#  u'methods',
#  u'metro',
#  u'milk',
#  u'mind',
#  u'mins',
#  u'mmm',
#  u'model',
#  u'mountain',
#  u'nature',
#  u'near',
#  u'negro',
#  u'next',
#  u'nokia',
#  u'nope',
#  u'ones',
#  u'outside',
#  u'packages',
#  u'pair',
#  u'param',
#  u'parma',
#  u'part',
#  u'paste',
#  u'path',
#  u'pay',
#  u'performance',
#  u'pics',
#  u'ping',
#  u'place',
#  u'plans',
#  u'please',
#  u'posted',
#  u'potentially',
#  u'president',
#  u'pricey',
#  u'problem',
#  u'project',
#  u'pugs',
#  u'puppet-lint',
#  u'quickly',
#  u'quite',
#  u'rain',
#  u'raining',
#  u'random',
#  u'readme',
#  u'ready',
#  u'regex',
#  u'remember',
#  u'research',
#  u'right\u2026',
#  u'root',
#  u'router',
#  u'running',
#  u'said',
#  u'schedule',
#  u'security',
#  u'self',
#  u'setup',
#  u'share',
#  u'ship',
#  u'showing',
#  u'sick',
#  u'side',
#  u'similar',
#  u'snapshot',
#  u'sounds',
#  u'spam',
#  u'specifically',
#  u'specified',
#  u'static',
#  u'stopped',
#  u'store',
#  u'strategy',
#  u'style',
#  u'sufficiently',
#  u'suggest',
#  u'support',
#  u'survive',
#  u'sweet',
#  u'tbh',
#  u'tea',
#  u'telstra',
#  u'things',
#  u'times',
#  u'titles',
#  u'toggl',
#  u'top',
#  u'train',
#  u'translate',
#  u'tree',
#  u'tried',
#  u'trust',
#  u'try',
#  u'useful',
#  u'users',
#  u'version',
#  u'volume',
#  u'wants',
#  u'watching',
#  u'water',
#  u'weather',
#  u'webex',
#  u'whatever',
#  u'wtf',
#  u'xD',
#  u'xkcd',
#  u'yea',
#  u'yep',
#  u'yesterday',
#  u'yo',
#  u'you\u2019ll',
#  u'\u2013',
#  u'$',
#  u"'M",
#  u"'master",
#  u"'sup",
#  u'**qemu',
#  u'*/sysfs',
#  u'*again',
#  u'*jealous*',
#  u'*nada',
#  u'*qmu',
#  u'*rageface*',
#  u'*s/get',
#  u'*say',
#  u'*sigh*',
#  u'+7',
#  u'-f',
#  u'-mtime',
#  u'-p',
#  u'-type',
#  u'.do',
#  u'//2.bp.blogspot.com/-lgBZGzX1OHQ/Tzsy9xL8W7I/AAAAAAAAbMQ/2Q7z6DKlyYw/s1600/FGDogInSocks.gif',
#  u'//4.bp.blogspot.com/-vC73kZRyAUw/UUcfKWeMx3I/AAAAAAAAApo/wKneG_JwFl4/s320/celebrating.jpg',
#  u'//ascii.io/',
#  u'//botcrawl.com/wp-content/uploads/2012/10/Get-out-Im-going-poo-cat-meme.png',
#  u'//cdn-static.cnet.co.uk/i/product_media/40000186/image5/440x330-nokia1616_01.jpg',
#  u'//cdn.shopify.com/s/files/1/0199/3340/files/ONL_17_JF_US_en_Daft_Punk_Contest.gif',
#  u'//commoncode.campfirenow.com/room/455251/transcript/message/960605259',
#  u'//d24w6bsrhbeh9d.cloudfront.net/photo/a09pn8O_700b.jpg',
#  u'//d24w6bsrhbeh9d.cloudfront.net/photo/aD0oj9Z_460s_v2.jpg',
#  u'//deathelectro.com/wp-content/audio/daft_punk.jpg',
#  u'//doblelol.com/uploads/4/funny-pugs-pictures.jpg',
#  u'//en.wikipedia.org/wiki/Regions_of_Light_and_Sound_of_God',
#  u'//en.wikipedia.org/wiki/The_Myth_of_Sisyphus',
#  u'//farm4.static.flickr.com/3380/5770051646_ccd89d97bc.jpg',
#  u'//git.io/PtC78Q',
#  u'//github.com/commoncode/hofbot/commit/2c6e00d7b562ae6b85426e66cddf9f5de4e6daec',
#  u'//github.com/commoncode/hofbot/commit/3029776e1bf33fa78e60485144894eb29e62df17',
#  u'//github.com/commoncode/hofbot/commit/367a7e502e5a885f1f61c6c927dc1ac0063baa58',
#  u'//github.com/commoncode/hofbot/commit/648bb1dbc1674f3725a11992606f55405987090f',
#  u'//github.com/commoncode/hofbot/commit/6c02b17ec9a98c9553efd45d87549cdd7c1e8c17',
#  u'//github.com/commoncode/hofbot/commit/d62b33409dd1e537dbb070db53edf87be6caeaaf',
#  u'//github.com/commoncode/hofbot/commit/db002c89bd5eac644a7a064992edc40912a2dd7f',
#  u'//github.com/commoncode/hofbot/commit/e67f78ba8f056d1658b10beb5861964c903ac1f0',
#  u'//github.com/commoncode/hofbot/commit/eeda29bdd1c4695ff83e85679a3ad3f6df245718',
#  u'//github.com/commoncode/puppetmaster/commit/19f7951cf215f689242648de330cda823248c88f',
#  u'//github.com/commoncode/puppetmaster/commit/418dd4307b760829979a17a2ad81e4366a0ffb71',
#  u'//github.com/commoncode/puppetmaster/commit/7d1e2b1e7ec15447faf021185f112f3ac9eca27d',
#  u'//github.com/commoncode/puppetmaster/commit/8dd85c409aec6935d06cdd002bfa2235571fdcdc',
#  u'//github.com/commoncode/puppetmaster/commit/f92f5b91cc1e0fbc251a95ac8522ba5af20c7938',
#  u'//i.imgur.com/082GhBf.gif',
#  u'//img70.imageshack.us/img70/4853/cutesquirrels27rn9.jpg',
#  u'//lahore.metblogs.com/archives/images/2007/07/McFlurry',
#  u'//lovelypackage.com/wp-content/uploads/2013/01/lovely-package-cat-lady-preserves-1.jpg',
#  u'//npmjs.org/package/newrelic',
#  u'//rymdkapsel.com/',
#  u'//soundcloud.com/platform/metro-area-br-berlin-melt',
#  u'//superpiadventures.com/2012/07/development-environment/',
#  u'//thepapermama.com/wp-content/uploads/anigif_enhanced-buzz-3194-1371300051-3.gif',
#  u'//thethousands.com.au/melbourne/eat-drink/shop-ramen',
#  u'//trello.com/c/520078a33df6de0a64002349',
#  u'//trello.com/c/lVdCdOOZ/22-everskill-trello-board-actions-to-common-code-logs-and-other-client-boards',
#  u'//twitter.com/counternotions/status/364592735556091904',
#  u'//upload.wikimedia.org/wikipedia/commons/6/65/Portland_metro_area.png',
#  u'//vergag.com/wp-content/uploads/2013/08/gif-gato1.gif',
#  u'//www.cutestpage.com/pictures/Red_Hoody_Cute_Pug.jpg',
#  u'//www.ebay.com.au/bhp/water-heater-element',
#  u'//www.ebay.com.au/itm/PORTABLE-IMMERSION-HOT-WATER-HEATER-ELEMENT-2400W-/290754704833',
#  u'//www.flickr.com/photos/41210280',
#  u'//www.instructables.com/id/Bulk-yoghurt-maker/',
#  u'//www.instructables.com/member/Starvinron/',
#  u'//www.memecenter.com/fun/703349/trying-to-quit-mc',
#  u'//www.quora.com/Ashton-Kutcher-1/How-did-Ashton-Kutcher-prepare-for-his-role-as-Steve-Jobs-in-the-new-movie-Jobs',
#  u'//www.squarefree.com/securitytips/web-developers.html',
#  u'//www.stovetop.com.au',
#  u'//www.tuexpertomovil.com/wp-content/uploads/2010/07/Nokia-1616-negro-azul.jpg',
#  u'//www.u2ugsm.com/blog/wp-content/uploads/2011/02/Nokia-1616-1800-LCD-display.jpg',
#  u'/dev',
#  u'/home/someuser/hofbotreponame',
#  u'/home/someuser/hofbotreponame.git',
#  u'/var/lib/puppet/reports',
#  u'01',
#  u'1.35.56',
#  u'10-11am',
#  u'10.36.52',
#  u'11',
#  u'1221',
#  u'1375871970514',
#  u'1375873599506',
#  u'140',
#  u'1440',
#  u'15',
#  u'1616-2b',
#  u'1616b',
#  u'1715879',
#  u'179261',
#  u'1986',
#  u'1\u20132',
#  u'2012',
#  u'2013',
#  u'2013-08-06',
#  u'2013-08-06T00:36:00+00:00',
#  u'2013-08-06T05:58:20+00:00',
#  u'2013-08-07T01:00:00+00:00',
#  u'20m',
#  u'20with',
#  u'24',
#  u'2400W',
#  u'25L',
#  u"26m's.jpg",
#  u'2pm',
#  u'30',
#  u'3030',
#  u'3G',
#  u'3pm',
#  u'3pm.',
#  u'4.5G',
#  u'446',
#  u'45',
#  u'48',
#  u'495',
#  u'5',
#  u'50',
#  u'5pm',
#  u'6',
#  u'60',
#  u'6c1897e6a194951ea55c82c05e18b79a3562e1e6',
#  u'7d1e2b1..8dd85c4',
#  u'80',
#  u'85476906',
#  u'8GB',
#  u'=',
#  u'==',
#  u'AAAAAaaaarrrrgggghhhh',
#  u'AAARFGGGHHGG',
#  u'ALIVE',
#  u'AM.png',
#  u'AND',
#  u'ARRIVED',
#  u'AVR',
#  u'Activity',
#  u'Adds',
#  u'Agile',
#  u'Ah',
#  u'Airport',
#  u'Almost',
#  u'Also',
#  u'Art',
#  u'Assigns',
#  u'Austin',
#  u'Awkward',
#  u'B-',
#  u'BAH',
#  u'BREACH',
#  u'BRUCE',
#  u'BULLSHIT',
#  u'BYE',
#  u'Basically',
#  u'Because',
#  u'Benji',
#  u'Bezos',
#  u'Bit',
#  u'Black',
#  u'Both',
#  u'Bugherd',
#  u'Bull',
#  u'Busted',
#  u'By',
#  u'CCCCCC',
#  u'CDN',
#  u'COT-800',
#  u'CRON',
#  u'Calculate',
#  u'Campfire',
#  u'Ceredwyn',
#  u'Ch',
#  u'Cities',
#  u'CodeWars',
#  u'Coming',
#  u'Compressing',
#  u'Convert',
#  u'Cool.',
#  u'Core',
#  u'Counting',
#  u'Creepy',
#  u'D',
#  u'DAMN',
#  u'DEBUG',
#  u'DSL',
#  u'DVD',
#  u'Darn',
#  u'Darshan',
#  u'Daz',
#  u'Delta',
#  u'Dev',
#  u'Doing',
#  u'Doubled',
#  u'End',
#  u'Events',
#  u'Excelent',
#  u'FACE',
#  u'FAR',
#  u'FFFFUUUUUUU',
#  u'FML',
#  u'FYI',
#  u'Fine',
#  u'Floyd',
#  u'Foundation',
#  u'GF',
#  u'GIF',
#  u'GO',
#  u'GPG',
#  u'Gents-',
#  u'Ghetto',
#  u'Gold',
#  u'HAHAHA',
#  u'HOFSTADTER',
#  u'HTML+javascript',
#  u'Hah',
#  u'Hahaha',
#  u'Hahahahaha',
#  u'He',
#  u'Hofbug-er',
#  u'Hubot',
#  u'IS',
#  u'ISP',
#  u'Ipython',
#  u'Is',
#  u'Its',
#  u'I\u2019d',
#  u'JUST',
#  u'James',
#  u'Jesran',
#  u'Jesrani*',
#  u'Jesse\u2019s',
#  u'Jim',
#  u'Keep',
#  u'LAN',
#  u'Let',
#  u'Lines',
#  u'Looking',
#  u'Luciano',
#  u'Lucy',
#  u'MUST',
#  u'MY',
#  u'Make',
#  u'Markdown',
#  u'Maybe',
#  u'Meh',
#  u'Melbourne',
#  u'Mentorloop/Bubbly',
#  u'Might',
#  u'Monoliths',
#  u'Mr',
#  u'Mythbusters',
#  u'N07/8763139776/',
#  u'NO',
#  u'NSFW',
#  u'Nah',
#  u'Need',
#  u'Negro',
#  u'Nevermind',
#  u'Niceee',
#  u'O.o',
#  u'On',
#  u'Only',
#  u'Or',
#  u'Original.',
#  u'PDF',
#  u'PM.png',
#  u'PPPoA',
#  u'PPPoE',
#  u'PR',
#  u'Patagonia.',
#  u'Perth',
#  u'Pink',
#  u'PoV',
#  u'Pretty',
#  u'Pushed',
#  u'PyConAU',
#  u'QEMU',
#  u'Queries',
#  u'Quora',
#  u'RDS',
#  u'RTS',
#  u'Rap',
#  u'Really',
#  u'Receive',
#  u'Record',
#  u'Remove',
#  u'Removes',
#  u'Route',
#  u'Run',
#  u'Rus',
#  u'S',
#  u'SOCKS',
#  u'SOOOOO',
#  u'SSL',
#  u'Shop',
#  u'Sisyphus',
#  u'Small',
#  u'Software',
#  u'Someone',
#  u'Sounds',
#  u'South',
#  u'Split',
#  u'State',
#  u'Sublime',
#  u'Submit',
#  u'Sup',
#  u'THE',
#  u'THERE',
#  u'Talk',
#  u'Telstra\u2019s',
#  u'Text',
#  u'Thats',
#  u'They',
#  u'Though',
#  u'Total',
#  u'Translates',
#  u'Triggers',
#  u'Try',
#  u'Twisted',
#  u'Twisted\u2026it\u2019s',
#  u'URL.',
#  u'Ugh',
#  u'Ulysses',
#  u'Unlock',
#  u'VMWare',
#  u'VMs',
#  u'VMware',
#  u'VirtualBox',
#  u'WAY',
#  u'WIP',
#  u'WORLD',
#  u'Was',
#  u'Whaaat',
#  u'Which',
#  u'Who',
#  u'Will',
#  u'Writing',
#  u'YAY',
#  u'Yay',
#  u'YouTube',
#  u'\\',
#  u'^^',
#  u'_every_',
#  u'_kinda_',
#  u'`image',
#  u'`query`.',
#  u'a6b32196-4cc8-474d-22bf-a880654982f8',
#  u'ability',
#  u'about.',
#  u'absurd',
#  u'account',
#  u'ace',
#  u'achievements/missions',
#  u'add',
#  u'addictive',
#  u'adding',
#  u'adds',
#  u'adhere',
#  u'affects',
#  u'afternoon',
#  u'agin',
#  u'ahha',
#  u'aight',
#  u'alert',
#  u'alerting',
#  u'alive',
#  u'almost',
#  u'along',
#  u'alright',
#  u'alternatives',
#  u'always',
#  u'ames',
#  u'amigo',
#  u'amrfark',
#  u'analyse',
#  u'android',
#  u'animated',
#  u'animations',
#  u'annoying',
#  u'ans2909891',
#  u'answer',
#  u'anyways',
#  u'app',
#  u'apparently',
#  u'appears',
#  u'appetising',
#  u'application/json',
#  u'application/x-javascript',
#  u'application/xml',
#  u'application/xml+rss',
#  u'apply',
#  u'appreciate',
#  u'approach',
#  u'apps',
#  u'areas',
#  u'arm',
#  u'arr',
#  u'arrggh',
#  u'arrogant',
#  u'ascii.io',
#  u'asked',
#  u'assigned',
#  u'assuming',
#  u'at=27',
#  u'attacker',
#  u'attacks',
#  u'aurelius',
#  u'auth',
#  u'authenticate',
#  u'automate',
#  u'available',
#  u'avoid',
#  u'aware',
#  u'away\u2026',
#  u'awesome',
#  u'backwards',
#  u'balanced',
#  u'ballz',
#  u'bars',
#  u'basically',
#  u'bastard',
#  u'batch',
#  u'battery',
#  u'beat',
#  u'beaten',
#  u'become',
#  u'beeeeep',
#  u'belle',
#  u'bench',
#  u'besides\u2026',
#  u'beta',
#  u'billable',
#  u'binutils',
#  u'bites',
#  u'bits',
#  u'blah',
#  u'blimey',
#  u'blocks',
#  u'boiler',
#  u'bomb',
#  u'bombs',
#  u'bonus',
#  u'booooooop',
#  u'booooop',
#  u'boop',
#  u'boss',
#  u'bought',
#  u'boy',
#  u'boys',
#  u'brain',
#  u'breach',
#  u'breach.png',
#  u'bread',
#  u'breathing',
#  u'brew',
#  u'bridged',
#  u'briefly',
#  u'bring',
#  u'bro',
#  u'brrrrrrreeep',
#  u'bruv',
#  u'btw',
#  u'bubble',
#  u'bud',
#  u'build',
#  u'built',
#  u'bung',
#  u'busy',
#  u'but\u2026',
#  u'buy',
#  u'bytes',
#  u'bytes/s',
#  u'c1291d549375cc2e5867564b6602a653',
#  u'cable',
#  u'calling',
#  u'came',
#  u'cames',
#  u'campfire/trello/toggl',
#  u'camplight',
#  u'caps',
#  u'cartoon',
#  u'catch',
#  u'catchy',
#  u'catgifs',
#  u'cause',
#  u'causes',
#  u'changed',
#  u'changing',
#  u'char',
#  u'characters',
#  u'chat',
#  u'cheap',
#  u'checked',
#  u'checkin',
#  u'checking',
#  u'checkout',
#  u'checks',
#  u'cheers',
#  u'chinese',
#  u'choc',
#  u'christ',
#  u'chuck',
#  u'chuckout',
#  u'circumvent',
#  u'class',
#  u'clean',
#  u'cleanup',
#  u'click\u2026',
#  u'cliff',
#  u'climbers',
#  u'closer',
#  u'codes',
#  u'comes',
#  u'comic',
#  u'comments',
#  u'common',
#  u'commoncode',
#  u'commoncode/puppetmaster.git',
#  u'commoncodes',
#  u'company',
#  u'compilation',
#  u'complicated',
#  u'compression',
#  u'computer',
#  u'computery',
#  u'conference',
#  u'consider',
#  u'content',
#  u'contest',
#  u'context',
#  u'continue',
#  u'contorl',
#  u'control',
#  u'convert',
#  u'cooker',
#  u'coolio',
#  u'coord',
#  u'copies',
#  u'copper.',
#  u'correct',
#  u'corrupt',
#  u'cos',
#  u'cosy',
#  u'count',
#  u'counternotions',
#  u'couple',
#  u'course',
#  u'cousin',
#  u'crap',
#  u'crapping',
#  u'crash',
#  u'crashes',
#  u'craving',
#  u'crazy',
#  u'created',
#  u'creating',
#  u'credentials',
#  u'creepy',
#  u'critique',
#  u'crockpot-thing',
#  u'cronjob',
#  u'cross',
#  u'cross\u2013compiled',
#  u'csrf',
#  u'culture',
#  u'currently',
#  u'curse',
#  u'customer',
#  u'cut',
#  u'cute',
#  u'cycle',
#  u'd',
#  u'dangnabit',
#  u'darshan',
#  u'dashboard',
#  u'databases',
#  u'dataset',
#  u'dates',
#  u'davids',
#  u'dawg',
#  u'dcofffee',
#  u'de',
#  u'dead',
#  u'debug',
#  u'declare',
#  u'default',
#  u'defaults',
#  u'degraded',
#  u'deleterious',
#  u'deploying',
#  u'deployment',
#  u'design',
#  u'desired',
#  u'dessert',
#  u'destroy',
#  u'detected',
#  u'developments',
#  u'devs',
#  u'diag',
#  u'die',
#  u'dinner',
#  u'dir\u2026that',
#  u'disable',
#  u'discount',
#  u'discuss',
#  u'disgusting',
#  u'docs',
#  u'document',
#  u'dog',
#  u'domain',
#  u'donesky',
#  u'don\u2019t',
#  u'double',
#  u'doubles',
#  u'downnnnn',
#  u'downtime',
#  u'dozen',
#  u'dressed',
#  u'drill',
#  u'drilled',
#  u'due',
#  u'dunno\u2026I',
#  u'duration',
#  u'd\xe6monised',
#  u'early',
#  u'easier',
#  u'easy',
#  u'eat',
#  u'eating',
#  u'edges',
#  u'edit',
#  u'editor',
#  u'eedeep',
#  u'effect',
#  u'eggs',
#  u'either',
#  u'element',
#  u'emails',
#  u'embed',
#  u'encryptedf',
#  u'endless',
#  u'ends',
#  u'enough',
#  u'ensure',
#  u'enter',
#  u'entirely',
#  u'environment.',
#  u'etc.',
#  u'ever',
#  u'everskill',
#  u'everyone',
#  u'evolve',
#  u'exact',
#  u'examples',
#  u'except',
#  u'excting',
#  u'expect',
#  u'expert',
#  u'exploit',
#  u'expression.',
#  u'extended',
#  u'extreme',
#  u'f',
#  u'f*ed',
#  u'fabfile',
#  u'fact',
#  u'fact\u2026',
#  u'failed',
#  u'fake',
#  u'fancy',
#  u'fast',
#  u'fatberg',
#  u'favourites',
#  u'feedback',
#  u'fencing',
#  u'fields',
#  u'files',
#  u'fill',
#  u'fit',
#  u'fixes',
#  u'flag',
#  u'flags',
#  u'flawlessly',
#  u'flickering',
#  u'flip.jpg',
#  u'folder',
#  u'followed',
#  u'follower',
#  u'follows',
#  u'foreground',
#  u'forget',
#  u'forgot',
#  u'fortune',
#  u'four',
#  u'fowlers',
#  u'freak',
#  u'freeing',
#  u'friends',
#  u'frustrating',
#  u'fucked',
#  u'fuckup',
#  u'fudge',
#  u'functioning',
#  u'funny',
#  u'fup',
#  u'gah',
#  u'gallon',
#  u'gardens/kitchens/quarters',
#  u'geared',
#  u'geist',
#  u'gem',
#  u'generic',
#  u'get/',
#  u'get/still',
#  u'gif',
#  u'github.com/commoncode/hofbot',
#  u'go.',
#  u'goes',
#  u'gone',
#  u'goodness',
#  u'gradually',
#  u'gray',
#  u'grooming\u201d',
#  u'guid',
#  u'guide',
#  u'guidelines',
#  u'gzip\u2026too',
#  u'g\u2019night',
#  u'ha',
#  u'hack',
#  u'hahah',
#  u'hahahah',
#  u'halp',
#  u'happy',
#  u'hassling',
#  u'hate',
#  u'haven\u2019t',
#  u'hay',
#  u'headway',
#  u'heaps',
#  u'hear',
#  u'heater',
#  u'hehhehe',
#  u'hell',
#  u'hellman',
#  u'helped',
#  u'helpful',
#  u'heritage',
#  u'hexa',
#  u'he\u2019s',
#  u'high',
#  u'hillbillies',
#  u'hipster',
#  u'hmm',
#  u'hmmmm',
#  u'hold',
#  u'holly',
#  u'home',
#  u'homedir',
#  u'hooks',
#  u'host',
#  u'hought',
#  u'hours\u201d',
#  u'household',
#  u'hover',
#  u'hrm',
#  u'hsmc',
#  u'huahaha',
#  u'huahahahaha',
#  u'huge',
#  u'hungry',
#  u'hurries',
#  u'ignoring',
#  u'iiNet',
#  u'images',
#  u'immediately',
#  u'immersion',
#  u'imminent',
#  u'impact',
#  u'import',
#  u'include',
#  u'included',
#  u'inconvenience',
#  u'incumbent',
#  u'indeed',
#  u'indeed.',
#  u'information',
#  u'inject',
#  u'insignificant',
#  u'instead.',
#  u'instructables',
#  u'interface',
#  u'intro',
#  u'intruder',
#  u'ircd-',
#  u'isn\u2019t',
#  u'issue.',
#  u'issues',
#  u'it.',
#  u'it..',
#  u'jeez',
#  u'jesrani',
#  u'joint',
#  u'judge',
#  u'just\u2013pushed',
#  u'keeping',
#  u'keeps',
#  u'keith-magee',
#  u'kennedy',
#  u'kewl',
#  u'kidding',
#  u'kind',
#  u'knew',
#  u'known',
#  u'lacks',
#  u'lady',
#  u'landlines',
#  u'latest',
#  u'laughings',
#  u'law',
#  u'leaf',
#  u'learn',
#  u'learned',
#  u'leaving',
#  u'lem',
#  u'length',
#  u'let',
#  u'licenses',
#  u'lid',
#  u'lights',
#  u'lil',
#  u'limit',
#  u'limitated',
#  u'limited',
#  u'lines',
#  u'link.',
#  u'links',
#  u'linted',
#  u'listen',
#  u'lists',
#  u'live',
#  u'loaf',
#  u'lock',
#  u'lodged',
#  u'logged',
#  u'logic',
#  u'longer',
#  u'loose',
#  u'lots',
#  u'loud',
#  u'love',
#  u'mac',
#  u'machine',
#  u'man',
#  u'managed',
#  u'many',
#  u'markhellewell',
#  u'marko',
#  u'mastery',
#  u'match',
#  u'mate',
#  u'math',
#  u'matter',
#  u'me`',
#  u'meant',
#  u'mebbe',
#  u'media',
#  u'meeting',
#  u'meetup',
#  u'melbdjango',
#  u'mention',
#  u'merge',
#  u'message',
#  u'message_960605259',
#  u'method',
#  u'middle',
#  u'mightn\u2019t',
#  u'mighty',
#  u'migration',
#  u'mini-mac',
#  u'minion',
#  u'minions',
#  u'miniscule',
#  u'missed',
#  u'missions:',
#  u'mistake',
#  u'mix',
#  u'mnths',
#  u'mo',
#  u'mobile',
#  u'modification',
#  u'modify',
#  u'module',
#  u'monions',
#  u'monitoring',
#  u'monolith',
#  u'month',
#  u'months',
#  u'morgan',
#  u'mornin',
#  u'motivation',
#  u'move',
#  u'muchacho',
#  u'muchachos',
#  u'multiplayer',
#  u'multiple',
#  u'mustaches',
#  u'mysteriously',
#  u'na',
#  u'name',
#  u'names',
#  u'nasty',
#  u'nata',
#  u'nee',
#  u'needed',
#  u'networking',
#  u'newer',
#  u'newrelic',
#  u'newspaper.',
#  u'nginx',
#  u'nick',
#  u'night',
#  u'nnnngh',
#  u'normal',
#  u'nose',
#  u'nothin',
#  u'not\u2026it\u2019s',
#  u'now\u2026or',
#  u'np',
#  u'number',
#  u'object',
#  u'objective',
#  u'odd',
#  u'offfering',
#  u'offline',
#  u'offloading',
#  u'ok\u2026',
#  u'one\u2013time',
#  u'online',
#  u'open',
#  u'opened',
#  u'opening',
#  u'operation',
#  u'optional',
#  u'orf',
#  u'others',
#  u'otherway',
#  u'out.',
#  u'outages',
#  u'ovaries',
#  u'packing',
#  u'page',
#  u'pages',
#  u'parameters',
#  u'parking',
#  u'parse',
#  u'parser',
#  u'past',
#  u'pasted',
#  u'payment',
#  u'peeps',
#  u'pepperoni+cheese',
#  u'periodically',
#  u'persisted',
#  u'phone\u201d',
#  u'photo',
#  u'pi',
#  u'pick',
#  u'picking',
#  u'picture',
#  u'pid',
#  u'piece',
#  u'pill',
#  u'pip',
#  u'pipe',
#  u'piss',
#  u'plan',
#  u'planned',
#  u'play',
#  u'playing',
#  u'point',
#  u'points',
#  u'pong',
#  u'popular',
#  u'possums',
#  u'post-receive',
#  u'post\u2013receive',
#  u'pot',
#  u'poured',
#  u'power',
#  u'pre-emptively',
#  u'preened',
#  u'preps',
#  u'presentation',
#  u'price',
#  u'print',
#  u'prints',
#  u'prioritise',
#  u'privileges',
#  u'pro',
#  u'prob',
#  u'prob.',
#  u'probabilities',
#  u'probability',
#  u'probabl',
#  u'probe',
#  u'problematic',
#  u'problems',
#  u'problem\u2026problem',
#  u'process',
#  u'programmatically',
#  u'prolly',
#  u'protection',
#  u'proxy\u2026in',
#  u'puppet-lint\u2019s',
#  u'puppetmaster\u2019s',
#  u'pushes',
#  u'pushing',
#  u'putting',
#  u'qemu',
#  u'qme',
#  u'que',
#  u'queue',
#  u'quick',
#  u'quirky',
#  u'raspberry',
#  u'rate',
#  u're-mounting',
#  u'reads',
#  u'reasons',
#  u'reason\u2026got',
#  u'reboot',
#  u'record',
#  u'recording',
#  u'reddit',
#  u'regard',
#  u'regions',
#  u'relationship',
#  u'relic',
#  u'relocate',
#  u'relocating',
#  u'relying',
#  u'removed',
#  u'reopened',
#  u'replaced',
#  u'replenishment',
#  u'reporting',
#  u'reporting\u2026but',
#  u'reports',
#  u'repository',
#  u'repo\u2014which',
#  u'required',
#  u'requirements\u2014prevent',
#  u'resize',
#  u'resources',
#  u'response',
#  u'responsible',
#  u'restaurants',
#  u'result.',
#  u'retrieve',
#  u'returned',
#  u'reused',
#  u'revision',
#  u'rewrite',
#  u're\u2013usable',
#  u'rig',
#  u'rm',
#  u'rolls',
#  u'routed',
#  u'routes',
#  u'routing',
#  u'ruby',
#  u'rules',
#  u'rules.',
#  u'runs',
#  u'russell',
#  u'rymdkapsel',
#  u'rymkadepsel',
#  u'sake',
#  u'savage',
#  u'saying',
#  u'scenario',
#  u'scene',
#  u'score',
#  u'scraped',
#  u'screen',
#  u'scroll',
#  u'scrum',
#  u'sealed',
#  u'searched',
#  u'second',
#  u'seconds',
#  u'seem',
#  u'seeya',
#  u'series',
#  u'served',
#  u'servername\u201d',
#  u'services',
#  u'sessions',
#  u'settled',
#  u'several',
#  u'sh*t',
#  u'shared',
#  u'shell',
#  u'shits',
#  u'shit\u2026',
#  u'shiz',
#  u'shoopers',
#  u'shoppe',
#  u'shopper',
#  u'short\u2013term',
#  u'show.',
#  u'side\u2013effect',
#  u'simple',
#  u'simplest',
#  u'since',
#  u'single',
#  u'sir',
#  u'sit',
#  u'sites',
#  u'size',
#  u'skipped',
#  u'slow',
#  u'small',
#  u'smashing',
#  u'solution',
#  u'solve',
#  u'somehow',
#  u'sometimes',
#  u'somewhere',
#  u'soon',
#  u'sort',
#  u'sound',
#  u'spanish',
#  u'special',
#  u'specific',
#  u'speech',
#  u'spent',
#  u'spewed',
#  u'spewing',
#  u'spider',
#  u'spilling',
#  u'spot',
#  u'spread',
#  u'squirrel',
#  u'stable',
#  u'stations',
#  u'status',
#  u'stole',
#  u'stolen',
#  u'storage',
#  u'stores',
#  u'straight',
#  u'straw',
#  u'street',
#  u'strong',
#  u'stuck',
#  u'stupid',
#  u'sub',
#  u'sublimate',
#  u'suck',
#  u'sucks',
#  u'suffer',
#  u'suggested',
#  u'suggestions',
#  u'sunday',
#  u'supermarket',
#  u'switch',
#  u'syntax',
#  u'system',
#  u'systems',
#  u'tags',
#  u'take',
#  u'takes',
#  u'taking',
#  u'tal',
#  u'talk',
#  u'tall',
#  u'tasks',
#  u'teh',
#  u'telco',
#  u'tell',
#  u'temperature',
#  u'terminal',
#  u'terribly',
#  u'testing',
#  u'tests',
#  u'tethering',
#  u'text/css',
#  u'text/html',
#  u'text/javascript',
#  u'text/plain',
#  u'text/xml',
#  u'thang',
#  u'that-',
#  u'that\u2019s',
#  u'that\u2026',
#  u'there\u2019s',
#  u'they\u2019ve',
#  u'thingy\u2026',
#  u'think:',
#  u'thinking',
#  u'this:',
#  u'thought',
#  u'thoughts',
#  u'thousand',
#  u'threads.',
#  u'three',
#  u'throw',
#  u'ti',
#  u'timer',
#  u'timing',
#  u'tip',
#  u'tired',
#  u'titles\u2014if',
#  u'titties',
#  u'tix\u2026',
#  u'today.',
#  u'todo',
#  u'took',
#  u'tools',
#  u'totally',
#  u'toward',
#  u'town',
#  u'track',
#  u'tracks',
#  u'training',
#  u'translation',
#  u'trawling',
#  u'trick',
#  u'tricky',
#  u'trigger',
#  u'trivially',
#  u'true',
#  u'tune',
#  u'turning',
#  u'ummm',
#  u'un-PC',
#  u'unaffected',
#  u'units',
#  u'units.',
#  u'unless',
#  u'update',
#  u'updates',
#  u'ups',
#  u'upstream',
#  u'url',
#  u'urn',
#  u'us',
#  u'username',
#  u'user\u2019s',
#  u'usually',
#  u'v.me',
#  u'v=5tiip5sJQAE',
#  u'v=G6NBAZrdjQw',
#  u'v=QllWNEGBKic',
#  u'v=R5ayo54J_u0',
#  u'vacola',
#  u'validate\u201d',
#  u'value',
#  u'verb',
#  u'verify',
#  u'via',
#  u'vicious',
#  u'video',
#  u'views',
#  u'virtualbox',
#  u'vmware',
#  u'vs.',
#  u'w/o',
#  u'waht',
#  u'wake',
#  u'walkthrough',
#  u'walrus',
#  u'wan',
#  u'watch',
#  u'way',
#  u'ways',
#  u'weapon',
#  u'weight',
#  u'weird',
#  u'we\u2019ll',
#  u'we\u2019re',
#  u'whats',
#  u'whether',
#  u'whinge',
#  u'wid',
#  u'wifi',
#  u'windows',
#  u'wire',
#  u'withdrawals',
#  u'within',
#  u'wo',
#  u'won',
#  u'wonder',
#  u'woot',
#  u'word',
#  u'worktree\u201d',
#  u'world',
#  u'worlds',
#  u'worry',
#  u'worrying',
#  u'worst',
#  u'worth',
#  u'wrap',
#  u'wrapper',
#  u'writing',
#  u'wrt',
#  u"y'know",
#  u'ya',
#  u'yah',
#  u'yeah\u2026',
#  u'years',
#  u'yer',
#  u'yesterday.',
#  u'yoghurt',
#  u'yogurt',
#  u'yogurth',
#  u'youtube',
#  u'yr',
#  u'yum-cha',
#  u'\xbfQu\xe9',
#  u'\u2019member',
#  u'\u2019net',
#  u'\u201cPersonal',
#  u'\u201ccommand\u201d',
#  u'\u201ccrontab\u201d',
#  u'\u201cdeploy\u201d',
#  u'\u201cdetached',
#  u'\u201cfind',
#  u'\u201cgit',
#  u'\u201cgit\u201d',
#  u'\u201cnegro',
#  u'\u201cpuppet',
#  u'\u201ctitle\u201d',
#  u'\u201ctypescript\u201d',
#  u'\u201cup',
#  u'\u201d',
#  u'\u2026it\u2019s']

# %% [markdown]
# <h3> Language Model </h3>
# <h2> A statical language model, its a set of probabilities asociated with words, and its occurrances in differentes sentences (Context of other words), in text. We will train some model with text, and from this model we will generate artificial sentences based on the probability of words to appear together.

# %%
words = []
for message in df.body:
    for word in word_tokenize(message):
        words.append(word)

# %%
text_model = nltk.Text(words)

# %%
text_model.generate(100)
# Out:
# Morning all , by all means : ) whisky omnom I 'm talking about circus
# , is working , search is working with osx . Ok , checking the response
# at the # codeshop I 'll hit the table. • encounter or be faced with (
# key , digstring ) where digstring uses django template dot notation to
# indicate hwo to get Goran here really You guys coming to MelbDjango
# tonight ? we talking about similar stuff i have this and now http : //
# 24.media.tumblr.com/0db6ba27b4b1bc25a5c5452af6ed65fa/tumblr_mpm2lwVBb6
# 1r3gb3zo1_400.gif haha oh my Hahaha : P Skipped the Toggl api ( my
# token ) ,

# %%
# Out:
# ['[', 'Moby', 'Dick', 'by', 'Herman', 'Melville', ...]

# %% [markdown]
# <h1> Can We use NLTK data for create a Language Model? Sure! </h1>

# %%
moby = nltk.Text(nltk.corpus.gutenberg.words('melville-moby_dick.txt'))

# %%
moby.generate(60)
# Out:
# [ Moby Dick . That was it without chewing , as a weaver ' s out of
# Nantucket with many others we spoke thirty different ships , and from
# the world ; put an end to his wearied mates , I following . Can it be
# vapour -- no absolute certainty can as yet had a little sweep do a

# %% [markdown]
# <h1>Excercise B: </h1>

# %% [markdown]
# <h2>Sentiment Analyisis</h2>
# <hr>

# %% [markdown]
# <h3> Is a phrase expresing a positive opinion? a negative opinion? how can we measure that? <h3>
#     <h3> We will decompose sentences into their smaller units: tokens, and we will measure how probable they distribute on positive/negative sentences along the text.

# %% [markdown]
# <h2>Before proceeding I need to explain something. Classification</h2>

# %% [markdown]
# <h3>In machine learning and statistics, classification is the problem of identifying to which of a set of categories (sub-populations) a new observation belongs, on the basis of a training set of data containing observations (or instances) whose category membership is known.  The individual observations are analyzed into a set of quantifiable properties, known as various explanatory variables, features, etc.</h3>

# %% [markdown]
# <h3> Looking the diagram. </h3>
# <h3><li> categories: Circle, Square</li></h3>
# <h3><li> new observation: new point in the 2D map </li></h3>
# <h3><li> features: IQ, Test Score. </li></h3>

# %% [markdown]
# <img height=500px width=600px src="http://georgemdallas.files.wordpress.com/2013/06/ml4.png">

# %% [markdown]
# <h2> Lets Classify Text! </h2>

# %%
#We will use movie reviews, already separated as positive and negative. Specially interest are those bigrams, 
#that are in positive or negative sentences (pair of words (word1, word2) that appear consecutives.)
from nltk.corpus import movie_reviews

# %%
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import movie_reviews

#This is the function that given a word, return a dict {word:True}. This will be our feature in the classifier. 
def word_feats(words):
    return dict([(word, True) for word in words])

#neg_ids, pos_ids keep all the files for negative reviews, and positive reviews respectively.
neg_ids = movie_reviews.fileids('neg')
pos_ids = movie_reviews.fileids('pos')

#So, lets take the positive/negative words, create the feature for such word, and store it in a negative/positive features list.
neg_feats = [(word_feats(movie_reviews.words(fileids=[f])), 'neg') for f in neg_ids]
pos_feats = [(word_feats(movie_reviews.words(fileids=[f])), 'pos') for f in pos_ids]

#Separating 3/4 of this featured words for training, 1/4 for test. 
neg_len_train = len(neg_feats)*3/4
pos_len_train = len(pos_feats)*3/4

train_feats = neg_feats[:neg_len_train] + pos_feats[:pos_len_train]
test_feats = neg_feats[neg_len_train:] + pos_feats[pos_len_train:]

#training a NaiveBayes Classifier with our training featured words.
classifier = NaiveBayesClassifier.train(train_feats)

#Lts check accuracy.
print 'accuracy: ', nltk.classify.util.accuracy(classifier, test_feats)

#Lets see which words fit best in each class.
classifier.show_most_informative_features()
# Out:
# accuracy:
# 0.728
# Most Informative Features
#              magnificent = True              pos : neg    =     15.0 : 1.0
#              outstanding = True              pos : neg    =     13.6 : 1.0
#                insulting = True              neg : pos    =     13.0 : 1.0
#               vulnerable = True              pos : neg    =     12.3 : 1.0
#                ludicrous = True              neg : pos    =     11.8 : 1.0
#                   avoids = True              pos : neg    =     11.7 : 1.0
#              uninvolving = True              neg : pos    =     11.7 : 1.0
#               astounding = True              pos : neg    =     10.3 : 1.0
#              fascination = True              pos : neg    =     10.3 : 1.0
#                  idiotic = True              neg : pos    =      9.8 : 1.0

# %%
classifier.

# %%
#SO WE TRAINED A CLASSIFIER FOR MOVIE REVIEWS. IT MEANS, FOR EVERY WORD THAT WE TRAINED, 
#IT NOWS THAT THIS WORD IS PROBABLE IN NEGATIVES WITH PROB P(W/POS) AND POSITIVE P(W/POS) (BAYES THEOREME).

# %%
sentence = "Colin is so miserable, it makes me amazing"
tokens = [word for word in word_tokenize(sentence) if word not in stops]

pos_tags = [pos for pos in pos_tag(tokens)]

pos_tags
# Out:
# [('Colin', 'NNP'),
#  ('miserable', 'JJ'),
#  (',', ','),
#  ('makes', 'VBZ'),
#  ('amazing', 'VBG')]

# %%
feats = word_feats( [word for (word,_) in pos_tags] )
feats
# Out:
# {',': True, 'Colin': True, 'amazing': True, 'makes': True, 'miserable': True}

# %%
classifier.classify(feats)
# Out:
# 'pos'

# %%
sentence = "Luchux is a miserable presenter, a destructor of devices and a horrible designer"
tokens = [word for word in word_tokenize(sentence) if word not in stops]

pos_tags = [pos for pos in pos_tag(tokens) if pos[1] == 'JJ']

pos_tags
# Out:
# [('miserable', 'JJ'), ('horrible', 'JJ')]

# %%
feats = word_feats( [word for (word,_) in pos_tags] )
feats
# Out:
# {'horrible': True, 'miserable': True}

# %%
classifier.classify(feats)
# Out:
# 'neg'

# %% [markdown]
# <h1> Another Excercise: Classifying News Documents in Categories: sport, humor, adventure, science fiction, etc... </h1>

# %%
from nltk.corpus import brown
from random import shuffle
from  nltk import NaiveBayesClassifier
from nltk import FreqDist
from nltk.classify import accuracy,apply_features
from nltk.corpus import stopwords

#given a document extract features (the presence or not of the best1500 top 1500 of freqDist of corpora)
def document_features(doc):
    doc_set_words = set(doc)
    features_dic = {} #features is a dictionary
    for word in best1500_words_corpora:
        features_dic['has(%s)' % word] = (word in doc_set_words)
    return features_dic

#Word frecuency of words in corpora. 
#Return the top 1500 most used words.
def init_corpora():
    words_in_corpora = FreqDist(w.lower() for w in brown.words())
    best1500 = words_in_corpora.keys()[:1500]
    return  nonstop(best1500)

#Receives a list of words, and remove those in stopwords.
def nonstop(listwords):
    return [word for word in listwords if word not in stopw]
  

stopw = stopwords.words('english')

best1500_words_corpora = init_corpora()
documents = [( list(nonstop(brown.words(fileid)) ),categoria) for categoria in brown.categories() for fileid in brown.fileids(categoria)]
shuffle(documents)
#print len(documents)
#print documents
doc_features_set = [(document_features(d),c) for (d,c) in documents]
#print len(doc_features_set)
train_set = doc_features_set[:350]
#train_set = apply_features(document,features,doc_features_set[:200])
test_set  = doc_features_set[150:]
classifier = NaiveBayesClassifier.train(train_set)
classifier.show_most_informative_features(30)

#We expect Adventura as 'cn02' contains words of a books of adventures
print classifier.classify(document_features(brown.words('cn02')))
#print accuracy(classifier,test_set)
# Out:
# Most Informative Features
#              has(didn't) = True           myster : learne =     35.2 : 1.0
#              has(agreed) = True           scienc : learne =     30.3 : 1.0
#               has(faith) = True           religi : learne =     25.2 : 1.0
#              has(church) = True           religi : learne =     25.2 : 1.0
#             has(stopped) = True           scienc : learne =     23.5 : 1.0
#                 has(ran) = True           advent : learne =     23.0 : 1.0
#             has(playing) = True            humor : learne =     22.2 : 1.0
#              has(season) = True           review : learne =     22.2 : 1.0
#                has(hair) = True           advent : learne =     21.6 : 1.0
#               has(teeth) = True            humor : belles =     21.0 : 1.0
#              has(you're) = True            humor : belles =     21.0 : 1.0
#            has(watching) = True           romanc : learne =     20.6 : 1.0
#                has(stay) = True           romanc : learne =     20.6 : 1.0
#            has(programs) = True           govern : belles =     19.6 : 1.0
#               has(don't) = True           myster : learne =     19.0 : 1.0
#             has(talking) = True           romanc : learne =     18.9 : 1.0
#                has(eyes) = True           advent : learne =     18.8 : 1.0
#           has(president) = True             news : learne =     18.2 : 1.0
#               has(solid) = True           review : belles =     18.2 : 1.0
#              has(caught) = True           advent : belles =     17.8 : 1.0
#                has(arms) = True           advent : learne =     17.5 : 1.0
#              has(dinner) = True            humor : learne =     17.3 : 1.0
#                 has(bit) = True            humor : learne =     17.3 : 1.0
#             has(evening) = True            humor : learne =     17.3 : 1.0
#           has(telephone) = True            humor : learne =     17.3 : 1.0
#                 has(hot) = True           romanc : learne =     17.3 : 1.0
#                has(1961) = True             news : belles =     17.2 : 1.0
#           has(afternoon) = True           fictio : learne =     17.1 : 1.0
#                 has(yes) = True           myster : learne =     17.1 : 1.0
#           has(apartment) = True           myster : learne =     17.1 : 1.0
# adventure

# %% [markdown]
# <h1> Django! </h1>
# <h2><li>The problem here arise when we want to keep these models to serve an API, or a view. </li></h2>
# <h2><li>This statistical models can be big enough to slow down the page, and we need to serve many request per second. </li></h2>
# <h2><li>pickling the models can help, not enough!</li></h2>
# <h2><li>Memcache properly configured can help, not enought!</li></h2>
# <h2><li>Celery tasks, RabbitMQ can help, we came closer here...</li></h2>
# <h2><li>I tried several approaches, and I don't know the way of provide realtime API served with Django</li></h2>
#
# <h2><li>Want to hear your opinions....</li></h2>

# %% [markdown]
# <h1> Thats all Folks! </h1>
#
# <h1> Questions?, Comments?, Opinions? </h1>

# %% [markdown]
# <h3> Keep working, research, dig, code, play with Natural Language Processing...</h3>

# %% [markdown]
# <img height=300px widht=300px src="http://sexualityinart.files.wordpress.com/2009/09/alan-turing-2.jpg">
